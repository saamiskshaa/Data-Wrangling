# %% [markdown]
# **Data Wrangling I**
#
#
# Perform the following operations using Python on any open source dataset (e.g., data.csv)
# 1. Import all the required Python Libraries.
# 2. Locate an open source data from the web (e.g., https://www.kaggle.com). Provide a clear
#  description of the data and its source (i.e., URL of the web site).
# 3. Load the Dataset into pandas dataframe.
# 4. Data Preprocessing: check for missing values in the data using pandas isnull(), describe()
# function to get some initial statistics. Provide variable descriptions. Types of variables etc.
# Check the dimensions of the data frame.
# 5. Data Formatting and Data Normalization: Summarize the types of variables by checking
# the data types (i.e., character, numeric, integer, factor, and logical) of the variables in the
# data set. If variables are not in the correct data type, apply proper type conversions.
# 6. Turn categorical variables into quantitative variables in Python.
# In addition to the codes and outputs, explain every operation that you do in the above steps and
# explain everything that you do to import/read/scrape the data set.

# %% [markdown]
# 1.1 import all the required Pyhton Libraries

# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %% [markdown]
#  Locate an open source data from the web (e.g., https://www.kaggle.com). Provide a clear
#  description of the data and its source (i.e., URL of the web site).

# %%
df = pd.read_csv("/content/autodata.csv")

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
df.head(10)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
# 5           5          2                122         audi        std
# 6           6          1                158         audi        std
# 7           7          1                122         audi        std
# 8           8          1                158         audi      turbo
# 9           9          2                192          bmw        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
# 5          two        sedan          fwd           front        99.8  ...
# 6         four        sedan          fwd           front       105.8  ...
# 7         four        wagon          fwd           front       105.8  ...
# 8         four        sedan          fwd           front       105.8  ...
# 9          two        sedan          rwd           front       101.2  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0        21          27  13495.0
# 1                9.0       111.0    5000.0        21          27  16500.0
# 2                9.0       154.0    5000.0        19          26  16500.0
# 3               10.0       102.0    5500.0        24          30  13950.0
# 4                8.0       115.0    5500.0        18          22  17450.0
# 5                8.5       110.0    5500.0        19          25  15250.0
# 6                8.5       110.0    5500.0        19          25  17710.0
# 7                8.5       110.0    5500.0        19          25  18920.0
# 8                8.3       140.0    5500.0        17          20  23875.0
# 9                8.8       101.0    5800.0        23          29  16430.0
#
#    city-L/100km horsepower-binned  diesel  gas
# 0     11.190476               Low       0    1
# 1     11.190476               Low       0    1
# 2     12.368421            Medium       0    1
# 3      9.791667               Low       0    1
# 4     13.055556               Low       0    1
# 5     12.368421               Low       0    1
# 6     12.368421               Low       0    1
# 7     12.368421               Low       0    1
# 8     13.823529            Medium       0    1
# 9     10.217391               Low       0    1
#
# [10 rows x 30 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['symboling'].plot(kind='hist', bins=20, title='symboling')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['normalized-losses'].plot(kind='hist', bins=20, title='normalized-losses')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['wheel-base'].plot(kind='hist', bins=20, title='wheel-base')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('make').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('aspiration').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('num-of-doors').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('body-style').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Unnamed: 0', y='symboling', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='symboling', y='normalized-losses', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='normalized-losses', y='wheel-base', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11.plot(kind='scatter', x='wheel-base', y='length', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('make')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='make', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('aspiration')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='aspiration', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('num-of-doors')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='num-of-doors', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_15.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('body-style')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='body-style', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['symboling'].plot(kind='line', figsize=(8, 4), title='symboling')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['normalized-losses'].plot(kind='line', figsize=(8, 4), title='normalized-losses')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['wheel-base'].plot(kind='line', figsize=(8, 4), title='wheel-base')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['aspiration'].value_counts()
#     for x_label, grp in _df_20.groupby('make')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('make')
# _ = plt.ylabel('aspiration')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['num-of-doors'].value_counts()
#     for x_label, grp in _df_21.groupby('aspiration')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('aspiration')
# _ = plt.ylabel('num-of-doors')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['body-style'].value_counts()
#     for x_label, grp in _df_22.groupby('num-of-doors')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('num-of-doors')
# _ = plt.ylabel('body-style')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['drive-wheels'].value_counts()
#     for x_label, grp in _df_23.groupby('body-style')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('body-style')
# _ = plt.ylabel('drive-wheels')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['make'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='Unnamed: 0', y='make', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['aspiration'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='Unnamed: 0', y='aspiration', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['num-of-doors'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='Unnamed: 0', y='num-of-doors', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_27['body-style'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_27, x='Unnamed: 0', y='body-style', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.tail()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make aspiration num-of-doors  \
# 196         196         -1                 95  volvo        std         four
# 197         197         -1                 95  volvo      turbo         four
# 198         198         -1                 95  volvo        std         four
# 199         199         -1                 95  volvo      turbo         four
# 200         200         -1                 95  volvo      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  \
# 196      sedan          rwd           front       109.1  ...
# 197      sedan          rwd           front       109.1  ...
# 198      sedan          rwd           front       109.1  ...
# 199      sedan          rwd           front       109.1  ...
# 200      sedan          rwd           front       109.1  ...
#
#      compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# 196                9.5       114.0    5400.0        23          28  16845.0
# 197                8.7       160.0    5300.0        19          25  19045.0
# 198                8.8       134.0    5500.0        18          23  21485.0
# 199               23.0       106.0    4800.0        26          27  22470.0
# 200                9.5       114.0    5400.0        19          25  22625.0
#
#      city-L/100km horsepower-binned  diesel  gas
# 196     10.217391               Low       0    1
# 197     12.368421            Medium       0    1
# 198     13.055556            Medium       0    1
# 199      9.038462               Low       1    0
# 200     12.368421               Low       0    1
#
# [5 rows x 30 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_28['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29['width'].plot(kind='hist', bins=20, title='width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30['curb-weight'].plot(kind='hist', bins=20, title='curb-weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_31['engine-size'].plot(kind='hist', bins=20, title='engine-size')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_32.groupby('aspiration').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_33.groupby('engine-type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_34.groupby('num-of-cylinders').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_35.groupby('fuel-system').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_36.plot(kind='scatter', x='Unnamed: 0', y='width', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37.plot(kind='scatter', x='width', y='curb-weight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38.plot(kind='scatter', x='curb-weight', y='engine-size', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_39.plot(kind='scatter', x='engine-size', y='bore', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['width']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_40.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('aspiration')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='aspiration', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('width')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['width']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_41.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('engine-type')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='engine-type', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('width')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['width']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_42.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('num-of-cylinders')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='num-of-cylinders', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('width')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['width']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_43.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('fuel-system')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='fuel-system', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('width')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_44['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_45['width'].plot(kind='line', figsize=(8, 4), title='width')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_46['curb-weight'].plot(kind='line', figsize=(8, 4), title='curb-weight')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_47['engine-size'].plot(kind='line', figsize=(8, 4), title='engine-size')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['engine-type'].value_counts()
#     for x_label, grp in _df_48.groupby('aspiration')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('aspiration')
# _ = plt.ylabel('engine-type')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['num-of-cylinders'].value_counts()
#     for x_label, grp in _df_49.groupby('engine-type')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('engine-type')
# _ = plt.ylabel('num-of-cylinders')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['fuel-system'].value_counts()
#     for x_label, grp in _df_50.groupby('num-of-cylinders')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('num-of-cylinders')
# _ = plt.ylabel('fuel-system')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['horsepower-binned'].value_counts()
#     for x_label, grp in _df_51.groupby('fuel-system')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('fuel-system')
# _ = plt.ylabel('horsepower-binned')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_52['aspiration'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_52, x='Unnamed: 0', y='aspiration', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_53['engine-type'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_53, x='Unnamed: 0', y='engine-type', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_54['num-of-cylinders'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_54, x='Unnamed: 0', y='num-of-cylinders', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_55['fuel-system'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_55, x='Unnamed: 0', y='fuel-system', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         201 non-null    int64
#  1   symboling          201 non-null    int64
#  2   normalized-losses  201 non-null    int64
#  3   make               201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
#  16  engine-size        201 non-null    int64
#  17  fuel-system        201 non-null    object
#  18  bore               201 non-null    float64
#  19  stroke             197 non-null    float64
#  20  compression-ratio  201 non-null    float64
#  21  horsepower         199 non-null    float64
#  22  peak-rpm           199 non-null    float64
#  23  city-mpg           201 non-null    int64
#  24  highway-mpg        201 non-null    int64
#  25  price              201 non-null    float64
#  26  city-L/100km       201 non-null    float64
#  27  horsepower-binned  199 non-null    object
#  28  diesel             201 non-null    int64
#  29  gas                201 non-null    int64
# dtypes: float64(11), int64(9), object(10)
# memory usage: 47.2+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  normalized-losses  wheel-base      length  \
# count  201.000000  201.000000          201.00000  201.000000  201.000000
# mean   100.000000    0.840796          122.00000   98.797015    0.837102
# std     58.167861    1.254802           31.99625    6.066366    0.059213
# min      0.000000   -2.000000           65.00000   86.600000    0.678039
# 25%     50.000000    0.000000          101.00000   94.500000    0.801538
# 50%    100.000000    1.000000          122.00000   97.000000    0.832292
# 75%    150.000000    2.000000          137.00000  102.400000    0.881788
# max    200.000000    3.000000          256.00000  120.900000    1.000000
#
#             width      height  curb-weight  engine-size        bore  \
# count  201.000000  201.000000   201.000000   201.000000  201.000000
# mean     0.915126   53.766667  2555.666667   126.875622    3.330692
# std      0.029187    2.447822   517.296727    41.546834    0.268072
# min      0.837500   47.800000  1488.000000    61.000000    2.540000
# 25%      0.890278   52.000000  2169.000000    98.000000    3.150000
# 50%      0.909722   54.100000  2414.000000   120.000000    3.310000
# 75%      0.925000   55.500000  2926.000000   141.000000    3.580000
# max      1.000000   59.800000  4066.000000   326.000000    3.940000
#
#            stroke  compression-ratio  horsepower     peak-rpm    city-mpg  \
# count  197.000000         201.000000  199.000000   199.000000  201.000000
# mean     3.256904          10.164279  103.396985  5117.587940   25.179104
# std      0.319256           4.004965   37.553843   480.521824    6.423220
# min      2.070000           7.000000   48.000000  4150.000000   13.000000
# 25%      3.110000           8.600000   70.000000  4800.000000   19.000000
# 50%      3.290000           9.000000   95.000000  5200.000000   24.000000
# 75%      3.410000           9.400000  116.000000  5500.000000   30.000000
# max      4.170000          23.000000  262.000000  6600.000000   49.000000
#
#        highway-mpg         price  city-L/100km      diesel         gas
# count   201.000000    201.000000    201.000000  201.000000  201.000000
# mean     30.686567  13207.129353      9.944145    0.099502    0.900498
# std       6.815150   7947.066342      2.534599    0.300083    0.300083
# min      16.000000   5118.000000      4.795918    0.000000    0.000000
# 25%      25.000000   7775.000000      7.833333    0.000000    1.000000
# 50%      30.000000  10295.000000      9.791667    0.000000    1.000000
# 75%      34.000000  16500.000000     12.368421    0.000000    1.000000
# max      54.000000  45400.000000     18.076923    1.000000    1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_56['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_57['symboling'].plot(kind='hist', bins=20, title='symboling')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_58['normalized-losses'].plot(kind='hist', bins=20, title='normalized-losses')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_59['wheel-base'].plot(kind='hist', bins=20, title='wheel-base')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_60.plot(kind='scatter', x='Unnamed: 0', y='symboling', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_61.plot(kind='scatter', x='symboling', y='normalized-losses', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_62.plot(kind='scatter', x='normalized-losses', y='wheel-base', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_63.plot(kind='scatter', x='wheel-base', y='length', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_64['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_65['symboling'].plot(kind='line', figsize=(8, 4), title='symboling')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_66['normalized-losses'].plot(kind='line', figsize=(8, 4), title='normalized-losses')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_67['wheel-base'].plot(kind='line', figsize=(8, 4), title='wheel-base')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_63.plot(kind='scatter', x='wheel-base', y='length', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.isnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make  aspiration  \
# 0         False      False              False  False       False
# 1         False      False              False  False       False
# 2         False      False              False  False       False
# 3         False      False              False  False       False
# 4         False      False              False  False       False
# ..          ...        ...                ...    ...         ...
# 196       False      False              False  False       False
# 197       False      False              False  False       False
# 198       False      False              False  False       False
# 199       False      False              False  False       False
# 200       False      False              False  False       False
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0           False       False         False            False       False  ...
# 1           False       False         False            False       False  ...
# 2           False       False         False            False       False  ...
# 3           False       False         False            False       False  ...
# 4           False       False         False            False       False  ...
# ..            ...         ...           ...              ...         ...  ...
# 196         False       False         False            False       False  ...
# 197         False       False         False            False       False  ...
# 198         False       False         False            False       False  ...
# 199         False       False         False            False       False  ...
# 200         False       False         False            False       False  ...
#
#      compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  price  \
# 0                False       False     False     False        False  False
# 1                False       False     False     False        False  False
# 2                False       False     False     False        False  False
# 3                False       False     False     False        False  False
# 4                False       False     False     False        False  False
# ..                 ...         ...       ...       ...          ...    ...
# 196              False       False     False     False        False  False
# 197              False       False     False     False        False  False
# 198              False       False     False     False        False  False
# 199              False       False     False     False        False  False
# 200              False       False     False     False        False  False
#
#      city-L/100km  horsepower-binned  diesel    gas
# 0           False              False   False  False
# 1           False              False   False  False
# 2           False              False   False  False
# 3           False              False   False  False
# 4           False              False   False  False
# ..            ...                ...     ...    ...
# 196         False              False   False  False
# 197         False              False   False  False
# 198         False              False   False  False
# 199         False              False   False  False
# 200         False              False   False  False
#
# [201 rows x 30 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_68.groupby('stroke').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_69.groupby('horsepower').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_70.groupby('peak-rpm').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_71.groupby('horsepower-binned').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['horsepower'].value_counts()
#     for x_label, grp in _df_72.groupby('stroke')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('stroke')
# _ = plt.ylabel('horsepower')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['peak-rpm'].value_counts()
#     for x_label, grp in _df_73.groupby('horsepower')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('horsepower')
# _ = plt.ylabel('peak-rpm')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['horsepower-binned'].value_counts()
#     for x_label, grp in _df_74.groupby('peak-rpm')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('peak-rpm')
# _ = plt.ylabel('horsepower-binned')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
df.notnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses  make  aspiration  num-of-doors  \
# 0          True       True               True  True        True          True
# 1          True       True               True  True        True          True
# 2          True       True               True  True        True          True
# 3          True       True               True  True        True          True
# 4          True       True               True  True        True          True
# ..          ...        ...                ...   ...         ...           ...
# 196        True       True               True  True        True          True
# 197        True       True               True  True        True          True
# 198        True       True               True  True        True          True
# 199        True       True               True  True        True          True
# 200        True       True               True  True        True          True
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0          True          True             True        True  ...
# 1          True          True             True        True  ...
# 2          True          True             True        True  ...
# 3          True          True             True        True  ...
# 4          True          True             True        True  ...
# ..          ...           ...              ...         ...  ...
# 196        True          True             True        True  ...
# 197        True          True             True        True  ...
# 198        True          True             True        True  ...
# 199        True          True             True        True  ...
# 200        True          True             True        True  ...
#
#      compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  price  \
# 0                 True        True      True      True         True   True
# 1                 True        True      True      True         True   True
# 2                 True        True      True      True         True   True
# 3                 True        True      True      True         True   True
# 4                 True        True      True      True         True   True
# ..                 ...         ...       ...       ...          ...    ...
# 196               True        True      True      True         True   True
# 197               True        True      True      True         True   True
# 198               True        True      True      True         True   True
# 199               True        True      True      True         True   True
# 200               True        True      True      True         True   True
#
#      city-L/100km  horsepower-binned  diesel   gas
# 0            True               True    True  True
# 1            True               True    True  True
# 2            True               True    True  True
# 3            True               True    True  True
# 4            True               True    True  True
# ..            ...                ...     ...   ...
# 196          True               True    True  True
# 197          True               True    True  True
# 198          True               True    True  True
# 199          True               True    True  True
# 200          True               True    True  True
#
# [201 rows x 30 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_75.groupby('stroke').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_76.groupby('horsepower').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_77.groupby('peak-rpm').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_78.groupby('horsepower-binned').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['horsepower'].value_counts()
#     for x_label, grp in _df_79.groupby('stroke')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('stroke')
# _ = plt.ylabel('horsepower')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['peak-rpm'].value_counts()
#     for x_label, grp in _df_80.groupby('horsepower')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('horsepower')
# _ = plt.ylabel('peak-rpm')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['horsepower-binned'].value_counts()
#     for x_label, grp in _df_81.groupby('peak-rpm')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('peak-rpm')
# _ = plt.ylabel('horsepower-binned')

# %%
df.notnull().sum()
# Out:
# Unnamed: 0           201
# symboling            201
# normalized-losses    201
# make                 201
# aspiration           201
# num-of-doors         201
# body-style           201
# drive-wheels         201
# engine-location      201
# wheel-base           201
# length               201
# width                201
# height               201
# curb-weight          201
# engine-type          201
# num-of-cylinders     201
# engine-size          201
# fuel-system          201
# bore                 201
# stroke               197
# compression-ratio    201
# horsepower           199
# peak-rpm             199
# city-mpg             201
# highway-mpg          201
# price                201
# city-L/100km         201
# horsepower-binned    199
# diesel               201
# gas                  201
# dtype: int64

# %%
#caLculate the mean value for "stroke" column
avg_stroke = df["stroke"].astype("float").mean(axis = 0)
print("Average of stroke :",avg_stroke)

#replace NaN by mean value in "stroke" column
df["stroke"].replace(np.nan, avg_stroke,inplace = True)
# Out:
# Average of stroke : 3.256903553299492

# %% [markdown]
# Calculate the mean value for the 'horsepower' column :

# %%
avg_hp=df["horsepower"].astype("float").mean(axis = 0)
print("Average of stroke :",avg_hp)
# Out:
# Average of stroke : 103.39698492462311

# %%
df['horsepower'].replace(np.nan,avg_hp,inplace = True)

# %%
from contextlib import nullcontext
df['num-of-doors'].value_counts()
# Out:
# four    115
# two      86
# Name: num-of-doors, dtype: int64

# %%
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
# replace the missing 'num-of-door' values by most frequent
df['num-of-doors'].replace(np.nan, "four" , inplace=True)

#simply drop whole row with nan in "Horsepower-banned" column
df.dropna(subset=['horsepower-binned'], axis=0 , inplace=True)

#reset index, because we dropped two rows
df.reset_index(drop=True, inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    0
# diesel               0
# gas                  0
# dtype: int64

# %% [markdown]
# DATA STANDARDIZATION : It is process of transforming data into common format which allows the researcher to make meaningful comparision

# %%
df['city-L/100km']=235/df['city-mpg']
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0        21          27  13495.0
# 1                9.0       111.0    5000.0        21          27  16500.0
# 2                9.0       154.0    5000.0        19          26  16500.0
# 3               10.0       102.0    5500.0        24          30  13950.0
# 4                8.0       115.0    5500.0        18          22  17450.0
#
#    city-L/100km horsepower-binned  diesel  gas
# 0     11.190476               Low       0    1
# 1     11.190476               Low       0    1
# 2     12.368421            Medium       0    1
# 3      9.791667               Low       0    1
# 4     13.055556               Low       0    1
#
# [5 rows x 30 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_82['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_83['symboling'].plot(kind='hist', bins=20, title='symboling')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_84['normalized-losses'].plot(kind='hist', bins=20, title='normalized-losses')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_85['wheel-base'].plot(kind='hist', bins=20, title='wheel-base')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_86.groupby('make').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_87.groupby('num-of-doors').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_88.groupby('body-style').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_89.groupby('drive-wheels').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_90.plot(kind='scatter', x='Unnamed: 0', y='symboling', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_91.plot(kind='scatter', x='symboling', y='normalized-losses', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_92.plot(kind='scatter', x='normalized-losses', y='wheel-base', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_93.plot(kind='scatter', x='wheel-base', y='length', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_94.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('make')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='make', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_95.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('num-of-doors')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='num-of-doors', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_96.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('body-style')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='body-style', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_97.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('drive-wheels')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='drive-wheels', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_98['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_99['symboling'].plot(kind='line', figsize=(8, 4), title='symboling')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_100['normalized-losses'].plot(kind='line', figsize=(8, 4), title='normalized-losses')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_101['wheel-base'].plot(kind='line', figsize=(8, 4), title='wheel-base')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['num-of-doors'].value_counts()
#     for x_label, grp in _df_102.groupby('make')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('make')
# _ = plt.ylabel('num-of-doors')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['body-style'].value_counts()
#     for x_label, grp in _df_103.groupby('num-of-doors')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('num-of-doors')
# _ = plt.ylabel('body-style')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['drive-wheels'].value_counts()
#     for x_label, grp in _df_104.groupby('body-style')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('body-style')
# _ = plt.ylabel('drive-wheels')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['engine-type'].value_counts()
#     for x_label, grp in _df_105.groupby('drive-wheels')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('drive-wheels')
# _ = plt.ylabel('engine-type')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_106['make'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_106, x='Unnamed: 0', y='make', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_107['num-of-doors'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_107, x='Unnamed: 0', y='num-of-doors', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_108['body-style'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_108, x='Unnamed: 0', y='body-style', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_109['drive-wheels'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_109, x='Unnamed: 0', y='drive-wheels', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df['highway-L/100km']=235/df["highway-mpg"]
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    horsepower  peak-rpm  city-mpg  highway-mpg    price city-L/100km  \
# 0       111.0    5000.0        21           27  13495.0    11.190476
# 1       111.0    5000.0        21           27  16500.0    11.190476
# 2       154.0    5000.0        19           26  16500.0    12.368421
# 3       102.0    5500.0        24           30  13950.0     9.791667
# 4       115.0    5500.0        18           22  17450.0    13.055556
#
#    horsepower-binned diesel  gas  highway-L/100km
# 0                Low      0    1         8.703704
# 1                Low      0    1         8.703704
# 2             Medium      0    1         9.038462
# 3                Low      0    1         7.833333
# 4                Low      0    1        10.681818
#
# [5 rows x 31 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_110['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_111['symboling'].plot(kind='hist', bins=20, title='symboling')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_112['normalized-losses'].plot(kind='hist', bins=20, title='normalized-losses')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_113['wheel-base'].plot(kind='hist', bins=20, title='wheel-base')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_114.groupby('make').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_115.groupby('num-of-doors').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_116.groupby('body-style').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_117.groupby('drive-wheels').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_118.plot(kind='scatter', x='Unnamed: 0', y='symboling', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_119.plot(kind='scatter', x='symboling', y='normalized-losses', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_120.plot(kind='scatter', x='normalized-losses', y='wheel-base', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_121.plot(kind='scatter', x='wheel-base', y='length', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_122.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('make')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='make', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_123.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('num-of-doors')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='num-of-doors', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_124.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('body-style')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='body-style', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['symboling']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_125.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('drive-wheels')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='drive-wheels', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('symboling')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_126['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_127['symboling'].plot(kind='line', figsize=(8, 4), title='symboling')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_128['normalized-losses'].plot(kind='line', figsize=(8, 4), title='normalized-losses')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_129['wheel-base'].plot(kind='line', figsize=(8, 4), title='wheel-base')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['num-of-doors'].value_counts()
#     for x_label, grp in _df_130.groupby('make')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('make')
# _ = plt.ylabel('num-of-doors')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['body-style'].value_counts()
#     for x_label, grp in _df_131.groupby('num-of-doors')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('num-of-doors')
# _ = plt.ylabel('body-style')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['drive-wheels'].value_counts()
#     for x_label, grp in _df_132.groupby('body-style')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('body-style')
# _ = plt.ylabel('drive-wheels')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['engine-type'].value_counts()
#     for x_label, grp in _df_133.groupby('drive-wheels')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('drive-wheels')
# _ = plt.ylabel('engine-type')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_134['make'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_134, x='Unnamed: 0', y='make', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_135['num-of-doors'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_135, x='Unnamed: 0', y='num-of-doors', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_136['body-style'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_136, x='Unnamed: 0', y='body-style', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_137['drive-wheels'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_137, x='Unnamed: 0', y='drive-wheels', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# DATA NORMALIZATION : It is process of transforming several values into similar range

# %%
df['length']=df['length']/df['length'].max()
df['width']=df['width']/df['width'].max()
df['height']=df['height']/df['height'].max()

# %%
df[['length','width','height']].head()

# %% [markdown]
# INDIACTOR VARIABLE : Indicator variable or dummy variable are used to label numerical variable used to label categories

# %%
df.columns

# %%
df['aspiration'].value_counts()

# %%
dummy_var_1=pd.get_dummies(df['aspiration'])
dummy_var_1.head()

# %%
df=pd.concat([df,dummy_var_1], axis=1)
df.drop('aspiration',axis = 1 , inplace = True)

# %%
df.head()

# %% [markdown]
# The last columns are indicator variable which are represented by 0's and 1's

# %%
df.columns

# %% [markdown]
# BINNING:
# It is process of transforming continous data into discrete categorical 'bins' for group analysis

# %%
df ["horsepower"]=df ["horsepower"].astype(float, copy=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import pyplot
import numpy as np

plt.matplotlib.pyplot.hist(df['wheel-base'])
plt.matplotlib.pyplot.xlabel('wheel-base')
plt.matplotlib.pyplot.ylabel('count')
plt.matplotlib.pyplot.title('wheel-base bins')

# %%
bins = np.linspace(min(df['wheel-base']),max(df['wheel-base']),4)
bins
